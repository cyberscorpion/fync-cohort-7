# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

# %%
# Load an example dataset
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="day",
    hue="smoker", style="smoker", size="size",
)

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.set_theme()
sns.kdeplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
col1 = np.linspace(1,10, 1000)
col2 = np.sin(col1)
df1 = pd.DataFrame({"C1": col1, "C2": col2})
df1.head()
# Out:
#          C1        C2
# 0  1.000000  0.841471
# 1  1.009009  0.846304
# 2  1.018018  0.851069
# 3  1.027027  0.855765
# 4  1.036036  0.860391

# %%
sns.lineplot(x = df1.C1, y = df1.C2, data = df1)
plt.show()

# %%
plt.figure(figsize = (5,3))
sns.set(rc = {'axes.facecolor' : 'cornflowerblue',
              'axes.grid' : False,
              'xtick.labelsize': 14,
              'ytick.labelsize' : 14
             })
sns.lineplot(x = df1.C1, y = df1.C2, data = df1)
plt.show()

# %% [markdown]
# ## Automobile dataset
# https://www.kaggle.com/datasets/toramky/automobile-dataset

# %%
df = pd.read_csv('Automobile_data.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
plt.figure(figsize=(7,5))
sns.lineplot(x = "wheel-base", y = "engine-size", data = df, linewidth=5)
plt.show()

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data = df["wheel-base"], linewidth=1.5, label='weel base')
sns.lineplot( data = df["engine-size"], linewidth=1.5, label='engine size')

plt.show()

# %%
plt.figure(figsize=(7,5))
sns.lineplot(x = "wheel-base", y = "engine-size", data = df, linewidth=1.5, hue="fuel-type", style="fuel-type", markers=True)
plt.show()

# %% [markdown]
# ## Fifa dataset
